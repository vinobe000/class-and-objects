# %%
class students():
  count=0
  def data(self,name,age,city):
    self.name=name
    self.age=age
    self.city=city
  def getdata(self):
    print(self.name)
    print(self.age)
    print(self.city)
    print(students.count)

# %%
ob1=students()
ob1.data("vinoth",22,"salem")
ob1.getdata()
# Out:
# vinoth
# 22
# salem
# 0

# %%
obj2=students()
obj2.data("kumar",22,"krishnagiri")
obj2.getdata()
# Out:
# kumar
# 22
# krishnagiri
# 0
